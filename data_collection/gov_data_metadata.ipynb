# %%
# !unzip ./dump_dataset.zip
# Out:
# Archive:  ./dump_dataset.zip
#   inflating: dump_dataset.csv

# %%
# !ls
# Out:
# dump_dataset.csv  dump_dataset.zip  gov_data_metadata.ipynb

# %%
# !nkf -w --overwrite dump_dataset.csv

# %%
import pandas as pd
from pandas import Series,DataFrame

# ファイルの読み込み
govmeta_df = pd.read_csv('dump_dataset.csv')

govmeta_df.head()
# Out:
# /usr/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (0,4,10,11,12,13,18,23,26,29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   日本語表記                                                 状態  \
# 0  英語表記                                              state
# 1  入力方式                                               択一選択
# 2    説明  データセットの状態を入力する。\nデータセットを登録または修正する場合は「active」、デ...
# 3    No                                                NaN
# 4     1                                             active
#
#                                         (データセット)タイトル  \
# 0                                              title
# 1                                               自由記述
# 2  データセットのタイトルを設定する。\n\n○○白書_××年度、◆◆調査_月報_△△月といった...
# 3                                                NaN
# 4                    消費者問題及び消費者政策に関する報告（2009〜2011年度）
#
# ...

# %%
govmeta_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250287 entries, 0 to 250286
# Data columns (total 31 columns):
# 日本語表記           250286 non-null object
# 状態              19537 non-null object
# (データセット)タイトル    19537 non-null object
# IT室用ID（MID）     19537 non-null object
# 府省用ID（SID）      6 non-null object
# (データセット)説明      13018 non-null object
# 公表組織名           19537 non-null object
# 連絡先             18670 non-null object
# 作成者             18629 non-null object
# グループタイトル        19534 non-null object
# タグ1             3 non-null object
# タグ2             3 non-null object
# タグ3             3 non-null object
# タグ4             3 non-null object
# タグ5             19151 non-null object
# リリース日           9228 non-null object
# 作成頻度            16060 non-null object
# 公開ウェブページ        8813 non-null object
# 対象地域            953 non-null object
# (リソース)タイトル      250278 non-null object
# URL             250278 non-null object
# (リソース)説明        97099 non-null object
# ...

# %%
col_rename = {'(データセット)タイトル':'title', 'リリース日':'release_data', 'データ形式':'file_type', 'ファイルサイズ':'file_size'}

# %%
govmeta_df.rename(columns=col_rename, inplace=True)
govmeta_df.head()
# Out:
#                                                title  \
# 0                                              title
# 1                                               自由記述
# 2  データセットのタイトルを設定する。\n\n○○白書_××年度、◆◆調査_月報_△△月といった...
# 3                                                NaN
# 4                    消費者問題及び消費者政策に関する報告（2009〜2011年度）
#
#                                         release_data  \
# 0                                       release_date
# 1                                   YYYY-MM-DD形式（半角）
# 2  データセットがウェブページへ掲載された日付（又は更新日付）を設定する。\n\n月や日が不明な...
# 3                                                NaN
# 4                                         2012-08-31
#
#                                            file_type Unnamed: 29 Unnamed: 30
# 0                                             format         NaN         NaN
# 1                                               択一選択         NaN         NaN
# 2  リソースに設定するリンク先のファイルの拡張子を設定する。\n\n選択肢のない拡張子の場合は設...         NaN         NaN
# ...

# %%
govmeta_df.drop(['Unnamed: 29', 'Unnamed: 30'], axis=1, inplace=True)

# %%
govmeta_df.head()
# Out:
#                                                title  \
# 0                                              title
# 1                                               自由記述
# 2  データセットのタイトルを設定する。\n\n○○白書_××年度、◆◆調査_月報_△△月といった...
# 3                                                NaN
# 4                    消費者問題及び消費者政策に関する報告（2009〜2011年度）
#
#                                         release_data  \
# 0                                       release_date
# 1                                   YYYY-MM-DD形式（半角）
# 2  データセットがウェブページへ掲載された日付（又は更新日付）を設定する。\n\n月や日が不明な...
# 3                                                NaN
# 4                                         2012-08-31
#
#                                            file_type
# 0                                             format
# 1                                               択一選択
# 2  リソースに設定するリンク先のファイルの拡張子を設定する。\n\n選択肢のない拡張子の場合は設...
# 3                                                NaN
# 4                                               HTML

# %%
govmeta_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250287 entries, 0 to 250286
# Data columns (total 3 columns):
# title           19537 non-null object
# release_data    9228 non-null object
# file_type       249695 non-null object
# dtypes: object(3)
# memory usage: 5.7+ MB
